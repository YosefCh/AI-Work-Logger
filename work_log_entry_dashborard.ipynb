# %% [markdown]
# ## __Work Log Entry__
#
# <div style="background-color:rgb(198, 206, 201);color:blue; padding:10px">
#
# ### __Enter or dictate raw log into Cell 3 and then hit the <span style="color:green">*Run All*</span> button above__
#
# </div>

# %%
from work_logs import WorkLog
work = WorkLog()

# %% [markdown]
# ### <strong style="color:teal">Optional:</strong> <i>Store notes here in this MD cell throught the day.</i>
#
# #### __Notes__:
#
# <div style="color:orange">
#
# <h2>This is for 2/5</h2><i></i>
#
#
# </div>
#
#
# <br>
# <br>
#
# ---

# %% [markdown]
# # __Cell 3__

# %%
raw_log = """

Today is Thursday help desk tickets. I just created a Word document for. Ticket involving a buyer request report that a user claimed was not sent to. We put all the details in the Word document of how to solve that. So Jeremy said that the PFEP went good. However, reality postscript that Memphis wants the vendor names all the lead time metrics added now. I did some researching on that and also remember what we spoke at the beginning. As of now that's not possible because we don't have those lead time metrics. The way it was done originally is that every. Every location had its CHEAT SHEET. I don't know if it was vendor specific or MC specific. And those were plugged in each time. We never had that data and Jeremy said it was not even that accurate. So I just used a default average from the data that I got and that's what we've been using till now. So I'm just gonna tell him that we're gonna that right now we don't have that data and. He can, he said. It wasn't that accurate. If we do get that data from each location for each vendor, then I would have to take a deep dive and see how difficult it would be to put that back in. OK I created a synopsis of my research today of. What exactly the lead times are affecting which metrics? Where they're derived from and what type of effort that would take, and I created a. Another markdown sell on the PFEP notebook, so we can use that for future reference.
Realized. I needed to put the location filter on the products. That extra page for Billy Lerman. We finished the other stuff but just added the location filter. Updated the app.
Created the. Additional pages on the 0002 Downtime Report remove the. However, it needs to be done on that report remove the classification field sorted descending. Although we must note that that can be changed anytime by user and we added a bunch of custom visuals. On another page. I guess I'll check that out with Alex.
Spend some time with Rachel. As there was a complex ticket regarding renaming by request reports, we went through what the process would be which blockers I might have. One of them is I cannot access the lock joint tube. Dev they use the VNC to access it. I might just use remote desktop. Went through some of the steps that will be quite a project.
  """

# %%
work.process_log(raw_log)
# Out:
# Step 1: Cleaning and formatting log...
#
# Step 2: Writing to text file...
# Work log written to file.
#
# Step 3: Generating keywords...
# Helpdesk ticket documentation, buyer request report, PFEP lead time metrics, PFEP notebook markdown cell, products extra page location filter, Billy Lerman, 0002 Downtime Report pages, custom visuals, Alex, Rachel, Lockjoint Tube Dev access VNC Remote Desktop
#
# Step 4: Writing to CSV...
# Work log written to CSV.
#
# ✓ All steps completed successfully!
# ...

# %% [markdown]
# ---
#
# ---
#
# ## This is for <u>[HELP-20802](https://lermanenterprise.atlassian.net/browse/HELP-20802)</u>
#
# As Per Rachel, this will be a large project with multiple steps.
#
# My first step is to reach out to Chelsie to see whether she has already started working on this. There are many steps involved, and I am still not fully clear on all of them yet.
#
# This request is for LJT (Lock Joint Tube). That identification comes from the directory structure that includes LEF. We will need to use WinAssist, select LJT, and check either AUTOSTREAM or STREAMXPASS to locate the script that runs these reports.
#
# The general approach is to:
#
# Enter the report name
#
# Identify the exact script and command that runs it (this still needs to be confirmed)
#
# All changes should be done in DEV first, not PROD.
#
# Once the correct script is identified:
#
# Search for the old name
#
# Update it to the new name
#
# The proper process is to:
#
# Copy the file from PROD to DEV, renaming it with a date
#
# Perform the copy via the command line in OneAssist (simple copy/paste is not reliable, per Rachel)
#
# Test everything thoroughly in DEV
#
# Only after successful testing, apply the changes in PROD
#
# Rachel also mentioned that there are additional future steps, including creating new byREQUEST templates.
